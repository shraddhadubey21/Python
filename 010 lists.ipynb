# %%
 l = [1,2,3,4,5]

# %%
l[1]
# Out:
# 2

# %%
l[1]=2

# %%
l[1]
# Out:
# 2

# %%
l.append(9)

# %%
l
# Out:
# [1, 2, 3, 4, 5, 9]

# %%
l.insert(3,10)

# %%
l
# Out:
# [1, 2, 3, 10, 4, 5, 9]

# %%
l.pop(6)
# Out:
# 9

# %%
l
# Out:
# [1, 2, 3, 10, 4, 5]

# %%
l.index(1)
# Out:
# 0

# %%
l
# Out:
# [1, 2, 3, 10, 4, 5]

# %%
l.index(3)
# Out:
# 2

# %%
l.append(10)

# %%
l
# Out:
# [1, 2, 3, 10, 4, 5, 10]

# %%
l.count(10)
# Out:
# 2

# %%
l.sort()

# %%
l
# Out:
# [1, 2, 3, 4, 5, 10, 10]

# %%
sorted(l)
# Out:
# [1, 2, 3, 4, 5, 10, 10]

# %%
sorted(newl)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 sorted(newl)
#
# NameError: name 'newl' is not defined

# %%
s="shraddha-sachin-shrachi"

# %%
s.split("-")
# Out:
# ['shraddha', 'sachin', 'shrachi']
