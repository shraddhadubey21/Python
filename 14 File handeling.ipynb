# %%
# read ,write and manipualte files store in disk.

# %%
f = open("text.txt","r")

# %%
f.read()
# Out:
# 'shraddha dubey'

# %%
s = "this is the right way to learn a data science"

# %%
f = open("harry.text","w")

# %%
f.write(s)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 f.write(s)
#
# ValueError: I/O operation on closed file.
