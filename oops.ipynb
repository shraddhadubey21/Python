# %%
# oops--> object orianted programm

# %%
class Employee:
    company = "HP"
    def __init__ (self, name, salary):
    self.name = name
    self.salary = salary
    def printDetails(self):
        print(f"The company of {self.name} is {self.company} with salary ${self.salry}")


e = Employee("harry",47000)
e.printDetails()
# Out:
#   Cell In[15], line 4
#     self.name = name
#     ^
# IndentationError: expected an indented block after function definition on line 3
