# %%
# unorderd ,mutable,key pair collections

# %%
d = {}

# %%
type(d)
# Out:
# dict

# %%
# Empty dictionary
empty_dict = {}

# Dictionary with key-value pairs
student = {
    "name": "Alice",
    "age": 25,
    "grade": "A"
}

# Using dict() constructor
person = dict(name="John", age=30, city="New York")

# %%
student
# Out:
# {'name': 'Alice', 'age': 25, 'grade': 'A'}

# %%
type(25)
# Out:
# int

# %%
student["name"]
# Out:
# 'Alice'

# %%
student["age"]
# Out:
# 25

# %%
student["name"]=shraddha
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 student["name"]=shraddha
#
# NameError: name 'shraddha' is not defined
