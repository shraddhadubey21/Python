# %%
a = 5
if(a>8):
    print("greater")
else:
    print("smaller")
# Out:
# smaller

# %%
a = 8
if(a<8):
    print("equal")
else:
    print("smaller")
# Out:
# smaller

# %%
def avg(a, b=0):
    return(a+b)/2

# %%
avg(4,6)
# Out:
# 5.0
