# %%
name =  "shraddha"

# %%
name
# Out:
# 'shraddha'

# %%
name.upper()
# Out:
# 'SHRADDHA'

# %%
name.endswith("ha")
# Out:
# True

# %%
name.startswith("pra")
# Out:
# False

# %%
a = 40
if a>60:
    print("greater than 60")
    elif(a>40):
