# %%
a = input("enter your name")
# Out:
# enter your name shraddha

# %%
b = input("enter your class")
# Out:
# enter your class 12th

# %%
a
# Out:
# 'shraddha'

# %%
b
# Out:
# '12th'

# %%
a+b
# Out:
# 'shraddha12th'

# %%
#jab 2 string hoti hai to unpe + opretor concation kar deta haii

# %%
c = input()
# Out:
#  21

# %%
c
# Out:
# '21'
