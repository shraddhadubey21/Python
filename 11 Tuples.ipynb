# %%
# its element cannot be modified.

# %%
e = ()

# %%
e
# Out:
# ()

# %%
type(e)
# Out:
# tuple

# %%
t = (1,2,3,4)

# %%
t
# Out:
# (1, 2, 3, 4)

# %%
type(t)
# Out:
# tuple

# %%
len(t)
# Out:
# 4

# %%
t[2]
# Out:
# 3

# %%
# Packing
person = ("Alice", 25, "Engineer")

# Unpacking
name, age, profession = person
print(name)  # Alice
print(age)   # 25
# Out:
# Alice
# 25
